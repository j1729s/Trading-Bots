# %% [markdown]
# # Data Driven Strategies

# %% [markdown]
# ## Importing Required Packages

# %%
import apmodule as ap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from IPython.display import display,display_html
from itertools import chain,cycle
plt.style.use('seaborn')
# %matplotlib inline

# %% [markdown]
# ## Required Functions:

# %%
# Function to perform training with giniIndex.
def tree_model(criterion="gini", max_depth=4):
  
    # Creating the classifier object
    clf = DecisionTreeClassifier(criterion = criterion,
            random_state = 42, max_depth=max_depth)

    return clf

def predict_tree_model(clf_object, X_train, y_train, X_test):
    
    clf_object.fit(X_train, y_train)
    
    return clf_object.predict(X_test), clf_object.predict(X_train)
      
# Function to calculate accuracy
def cal_metrics(y_test, y_train, y_test_pred, y_train_pred):
      
    print("Confusion Matrix:\n",
          metrics.confusion_matrix(y_test, y_test_pred))

    print('\nIn-Sample Accuracy:\n', 
          round(metrics.accuracy_score(y_train, y_train_pred), 3))
    
    print('\nOut-of-Sample Accuracy:\n', 
          round(metrics.accuracy_score(y_test, y_test_pred), 3))

def plot_portfolio(data, title_name, kind='line', ylabel='Portfolio Value', logy=False):
    """
    Generates Portfolio Plot
    
    :param data: portfolio price dataset
    :param title_name: 'Qunatile Portfolio '+'title_name'
    :param kind: the kind of graph eg, line, bar hist
    :param ylabel: specify ylabel
    :param logy: specify True or False
    """
    # Plotting the data
    data.plot(figsize=(11,5),
                 kind=kind,
                 title='Portfolio: '+f'{title_name}',
                 xlabel='Time',
                 ylabel=ylabel,
                 logy=logy) #the last argument specifies log-scale for the Y axis

def ml_analysis(prediction, prices):
    
    #We capture the name of the factor using the .name attribute to use it later
    pred_name = prediction.name
    
    #We look for the tag of the best and worst outcome
    best = prediction.max()
    worst = prediction.min()
    
    #We calculate the future returns
    future_returns = np.log(prices.groupby('id').shift(-1) / prices).rename('fut_ret')
    
    #We join the signal with the future returns
    data = prediction.to_frame().join(future_returns).dropna()
    
    #We calculate the average return of the groups
    portfolios = data.groupby(['date',pred_name]).mean()
    
    #We rearrange the results in order to have one group per column
    port_returns = portfolios['fut_ret'].unstack(level=1) 
    
    #We calculate the benchmark return
    benchmark_return = data.groupby('date')['fut_ret'].mean().rename('Benchmark')
    port_returns = port_returns.join(benchmark_return.to_frame())
    
    #We calculate the return of the zero-investment portfolios
    port_returns['Active'] = port_returns[best] - port_returns['Benchmark']
    port_returns['Neutral'] = port_returns[best] - port_returns[worst]
    
    diagnostics = ap.diagnostics(port_returns)

    return port_returns, diagnostics 
    
def display_side_by_side(*args,titles=cycle([''])):
    """
    Generates side by side HTML plot of pandas dataframes
    
    :param *args: Used to pass a variable number of arguments
    :param titles: the user provided titles for the HTML plot, default ''
    """
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        
        # Setting Alignment
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        
        # Aligning the Title
        html_str+=f'<h2 style="text-align: center;">{title}</h2>' 
        
        # Replacing with the table and setting the display style to inline
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    
    # Displaying the dataframe
    display_html(html_str,raw=True)

# %% [markdown]
# ## Loading and preprocessing the Data

# %%
# we load the prices and calculate the future returns
prices = pd.read_csv('Prices.zip', parse_dates=['date']).set_index(['id', 'date'])
returns = np.log(prices['price'].groupby('id').shift(-1) / prices['price']).rename('fut_ret')

# we load the factors data
factors = pd.read_csv('A2_Data.zip', parse_dates=['date']).set_index(['id', 'date'])

# we join the two dataframes into one
sample = factors.join(returns).dropna()

# we calculate the median and join into dataframe
median = sample.groupby('date')['fut_ret'].median().rename('median')
sample = sample.join(median).dropna()

# we calculate the signal and turn boolean values into numerical for better modelling
sample['target'] = sample['fut_ret'].groupby('id').shift(0) > sample['median'].groupby('id').shift(1)
structure = {True: 1, False: 0}
sample['target'] = sample['target'].map(structure)

# we drop the first row of every id
#sample.drop(sample.groupby('id').head(1).index, inplace=True)

sample
# Out:
#                         gp     mom12       epq    n_beta  fed_rate  \
# id    date
# 10001 2008-05-30 -0.015003  0.321977  0.477049  1.349476      2.00
#       2008-06-30 -0.015474  0.861761  0.418016  1.376280      2.01
#       2008-07-31 -0.028595  0.970066  0.447758  1.371320      2.00
#       2008-08-29 -0.027791  0.848705  0.295819  1.379083      1.81
#       2008-10-31 -0.644914  0.670253  0.149691  1.362214      0.39
# ...                    ...       ...       ...       ...       ...
# 93436 2021-07-30  0.190919  1.518636  0.166994 -0.640392      0.09
#       2021-08-31  0.169477  0.869417  0.138092 -0.637089      0.08
#       2021-09-30  0.157910 -0.002322  0.133930 -0.609448      0.08
#       2021-10-29  0.324550  0.469341  0.148780 -0.729108      0.08
#       2021-11-30  0.333179  1.899733  0.159068 -0.712888      0.08
#
#                   unemploy_rate   fut_ret    median  target
# id    date
# 10001 2008-05-30            5.6 -0.010143 -0.089785       0
#       2008-06-30            5.8 -0.054481  0.006252       1
#       2008-07-31            6.1 -0.019921  0.022162       0
#       2008-08-29            6.1 -0.147774 -0.102995       0
#       2008-10-31            6.8 -0.139401 -0.127733       0
# ...                         ...       ...       ...     ...
# 93436 2021-07-30            5.2  0.068224  0.011490       1
#       2021-08-31            4.7  0.052633 -0.046132       1
#       2021-09-30            4.6  0.362230  0.029903       1
#       2021-10-29            4.2  0.027238 -0.037697       0
#       2021-11-30            3.9 -0.079968  0.041303       0
#
# [325903 rows x 9 columns]

# %% [markdown]
# ## Splitting into Train and Test sets

# %%
# we select features/factors for the model
features = ['gp', 'mom12', 'epq', 'n_beta', 'fed_rate', 'unemploy_rate']

# X is the factors and y is the target variable
X = sample[features]
y = sample[['target']]

# we split the data into train and test sets categorised by date
idx = pd.IndexSlice
X_train, X_test = X.loc[idx[:,'01-01-2008':'31-12-2017'], :], X.loc[idx[:,'01-01-2018':'31-12-2021'], :]
y_train, y_test = y.loc[idx[:,'01-01-2008':'31-12-2017'], :], y.loc[idx[:,'01-01-2018':'31-12-2021'], :]
# Out:
# C:\Users\franc\anaconda3\lib\site-packages\pandas\core\indexes\multi.py:3197: UserWarning: Parsing '31-12-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   start = stop = level_index.slice_indexer(key.start, key.stop, key.step)
# C:\Users\franc\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6393: UserWarning: Parsing '31-12-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   label = self._maybe_cast_slice_bound(label, side)
# C:\Users\franc\anaconda3\lib\site-packages\pandas\core\indexes\multi.py:3197: UserWarning: Parsing '31-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   start = stop = level_index.slice_indexer(key.start, key.stop, key.step)
# C:\Users\franc\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6393: UserWarning: Parsing '31-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   label = self._maybe_cast_slice_bound(label, side)

# %% [markdown]
# ## Predicting through Decision Tree Models

# %%
clf = tree_model()
y_test_pred, y_train_pred = predict_tree_model(clf, X_train, y_train, X_test)
cal_metrics(y_test, y_train, y_test_pred, y_train_pred)
print('\n10-Folds Cross Validation Average Accuracy:\n', 
          round(cross_val_score(tree_model(), X, y, cv=10).mean(), 3))
# Out:
# Confusion Matrix:
#  [[17934 27038]
#  [14769 24710]]
#
# In-Sample Accuracy:
#  0.537
#
# Out-of-Sample Accuracy:
#  0.505
#
# 10-Folds Cross Validation Average Accuracy:
#  0.534

# %%
y_test_pred1, y_train_pred1 = predict_tree_model(tree_model(criterion="entropy"), X_train, y_train, X_test)
cal_metrics(y_test, y_train, y_test_pred1, y_train_pred1)
print('\n10-Folds Cross Validation Average Accuracy:\n', 
          round(cross_val_score(tree_model(criterion="entropy"), X, y, cv=10).mean(), 3))
# Out:
# Confusion Matrix:
#  [[17934 27038]
#  [14769 24710]]
#
# In-Sample Accuracy:
#  0.537
#
# Out-of-Sample Accuracy:
#  0.505
#
# 10-Folds Cross Validation Average Accuracy:
#  0.534

# %%
features = pd.DataFrame(clf.feature_importances_, columns=['Feature Importance'], index=X.columns)
features
# Out:
#                Feature Importance
# gp                       0.002881
# mom12                    0.001689
# epq                      0.000000
# n_beta                   0.000000
# fed_rate                 0.788973
# unemploy_rate            0.206457

# %%
# We can even plot it if we want
features[features['Feature Importance']>0].plot(kind='pie', 
              y='Feature Importance',
              figsize=(10,6),
              fontsize=14)
# Out:
# <AxesSubplot:ylabel='Feature Importance'>

# %%
os_pred = pd.Series(y_test_pred.astype('int64'), index = y_test.index).rename('Winner')
ret, dia = ml_analysis(os_pred, prices.squeeze())
dia
# Out:
#                      0         1  Benchmark    Active   Neutral
# Mean Return  -0.071668  0.098966   0.020878 -0.069083 -0.570613
# St. Dev.      0.292697  0.223527   0.248453  0.063023  0.103231
# RR Ratio     -0.244852  0.442747   0.084032 -1.096142 -5.527530
# % Positive    0.611111  0.606061   0.617021  0.000000  0.000000
# Worst Month  -0.279488 -0.138644  -0.279488 -0.086349 -0.086398
# Best Month    0.148179  0.163447   0.163447  0.000000 -0.015429
# Max DrawDown       NaN -0.086751  -0.452643 -0.174575       NaN

# %%
port_values = ret.cumsum().apply(np.exp)

port_values[[0, 1, 'Benchmark']].plot(figsize=(10,6),
                                      title='Machine Learning Strategy', 
                                      ylabel='Portfolio Value', 
                                      xlabel='Time')
# Out:
# <AxesSubplot:title={'center':'Machine Learning Strategy'}, xlabel='Time', ylabel='Portfolio Value'>

# %%
ret
# Out:
#                    0         1  Benchmark    Active   Neutral
# date
# 2018-01-31 -0.050782       NaN  -0.050782       NaN       NaN
# 2018-02-28  0.000789       NaN   0.000789       NaN       NaN
# 2018-03-29 -0.001900       NaN  -0.001900       NaN       NaN
# 2018-04-30  0.035935       NaN   0.035935       NaN       NaN
# 2018-05-31  0.003737       NaN   0.003737       NaN       NaN
# 2018-06-29  0.006431       NaN   0.006431       NaN       NaN
# 2018-07-31  0.016403       NaN   0.016403       NaN       NaN
# 2018-08-31 -0.024693       NaN  -0.024693       NaN       NaN
# 2018-09-28       NaN -0.109512  -0.109512  0.000000       NaN
# 2018-10-31       NaN -0.007664  -0.007664  0.000000       NaN
# 2018-11-30       NaN -0.138644  -0.138644  0.000000       NaN
# 2018-12-31       NaN  0.112445   0.112445  0.000000       NaN
# 2019-01-31       NaN  0.036628   0.036628  0.000000       NaN
# 2019-02-28       NaN -0.023365  -0.023365  0.000000       NaN
# 2019-03-29       NaN  0.022975   0.022975  0.000000       NaN
# 2019-04-30       NaN -0.103976  -0.103976  0.000000       NaN
# 2019-05-31       NaN  0.054527   0.054527  0.000000       NaN
# 2019-06-28       NaN -0.007745  -0.007745  0.000000       NaN
# 2019-07-31       NaN -0.061264  -0.061264  0.000000       NaN
# 2019-08-30       NaN  0.032096   0.032096  0.000000       NaN
# 2019-09-30 -0.004467       NaN  -0.004467       NaN       NaN
# 2019-10-31  0.017717       NaN   0.017717       NaN       NaN
# 2019-11-29  0.030557       NaN   0.030557       NaN       NaN
# 2019-12-31 -0.033683       NaN  -0.033683       NaN       NaN
# 2020-01-31 -0.096917       NaN  -0.096917       NaN       NaN
# 2020-02-28 -0.279488       NaN  -0.279488       NaN       NaN
# 2020-03-31  0.148179  0.132750   0.148153 -0.015402 -0.015429
# 2020-04-30  0.051267  0.014172   0.051204 -0.037032 -0.037095
# 2020-05-29  0.039265 -0.012017   0.039178 -0.051194 -0.051282
# 2020-06-30  0.034147 -0.052251   0.034098 -0.086349 -0.086398
# 2020-07-31       NaN  0.031718   0.031718  0.000000       NaN
# 2020-08-31       NaN -0.039564  -0.039564  0.000000       NaN
# 2020-09-30       NaN  0.005931   0.005931  0.000000       NaN
# 2020-10-30       NaN  0.163447   0.163447  0.000000       NaN
# 2020-11-30       NaN  0.065731   0.065731  0.000000       NaN
# 2020-12-31       NaN  0.064373   0.064373  0.000000       NaN
# 2021-01-29       NaN  0.069750   0.069750  0.000000       NaN
# 2021-02-26       NaN  0.025057   0.025057  0.000000       NaN
# 2021-03-31       NaN  0.019890   0.019890  0.000000       NaN
# 2021-04-30       NaN  0.015168   0.015168  0.000000       NaN
# 2021-05-28       NaN  0.008703   0.008703  0.000000       NaN
# 2021-06-30       NaN -0.024029  -0.024029  0.000000       NaN
# 2021-07-30       NaN  0.011239   0.011239  0.000000       NaN
# 2021-08-31       NaN -0.039209  -0.039209  0.000000       NaN
# 2021-09-30       NaN  0.028252   0.028252  0.000000       NaN
# 2021-10-29       NaN -0.047291  -0.047291  0.000000       NaN
# 2021-11-30       NaN  0.023834   0.023834  0.000000       NaN

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# we create an empty dataframe to store the results
optimal = pd.DataFrame()

# we start the loop
for depth in range(1,10):
    
    y_test_pred, y_train_pred = predict_tree_model(tree_model(max_depth=depth), X_train, y_train, X_test)

    # we run the 10-fold cross validation on the train set only
    os_pred = pd.Series(y_test_pred.astype('int64'), index = y_test.index).rename('Winner')
    ret, dia = ml_analysis(os_pred, prices.squeeze())       
    
    # we save the average accuracy (and the number of neighbors)
    optimal.loc[depth, 'Information Ratio'] = dia.loc['RR Ratio', 'Active']

# we plot
optimal.plot(figsize=(10,6), 
             style='r-o',
             xlabel='Tree Depth',
             ylabel='10-Folds Average Out-of-Sample Accuracy',
             title='Hyperparameter Tuning')
# Out:
# <AxesSubplot:title={'center':'Hyperparameter Tuning'}, xlabel='Tree Depth', ylabel='10-Folds Average Out-of-Sample Accuracy'>

# %% [markdown]
# ## Bagging

# %%
rnf = RandomForestClassifier(max_depth=optimal['Information Ratio'].idxmax(), random_state = 42)
rnf.fit(X_train, y_train)

# We build our out-of-sample predictions
y_test_pred = rnf.predict(X_test)

# We can measure the out-of-sample accuracy
os_accuracy = metrics.accuracy_score(y_test, y_test_pred)
print('Out-of-Sample Accuracy:', round(os_accuracy, 3), '\n')

# We can measure the out-of-sample simulated investment performance
os_pred = pd.Series(y_test_pred.astype('int64'), index = y_test.index).rename('Winner')
ret, dia = ml_analysis(os_pred, prices.squeeze())
display(dia)
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_29084\2781799105.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rnf.fit(X_train, y_train)
# Out-of-Sample Accuracy: 0.522
#                      0         1  Benchmark    Active   Neutral
# Mean Return  -0.124567 -0.008213   0.020878  0.027781  0.255645
# St. Dev.      0.318473  0.266541   0.248453  0.051847  0.177370
# RR Ratio     -0.391138 -0.030814   0.084032  0.535834  1.441309
# % Positive    0.553191  0.700000   0.617021  0.666667  0.666667
# Worst Month  -0.279453 -0.291681  -0.279488 -0.039444 -0.083556
# Best Month    0.201005  0.129076   0.163447  0.027032  0.137893
# Max DrawDown -0.733320 -0.048961  -0.452643 -0.072012 -0.148247

# %%
rnf_features = pd.DataFrame(rnf.feature_importances_, columns=['Feature Importance'], index=X.columns)
rnf_features
# Out:
#                Feature Importance
# gp                       0.021934
# mom12                    0.034869
# epq                      0.068261
# n_beta                   0.016830
# fed_rate                 0.534809
# unemploy_rate            0.323297

# %%
# We can even plot it if we want
rnf_features[rnf_features['Feature Importance']>0].plot(kind='pie', 
                                                        y='Feature Importance',
                                                        figsize=(10,6),
                                                        fontsize=14)
# Out:
# <AxesSubplot:ylabel='Feature Importance'>

# %% [markdown]
# ## Boosting

# %%
gbt = GradientBoostingClassifier(max_depth=optimal['Information Ratio'].idxmax(), random_state = 42)
gbt.fit(X_train, y_train)

# We build our out-of-sample predictions
y_test_pred = gbt.predict(X_test)

# We can measure the out-of-sample accuracy
os_accuracy = metrics.accuracy_score(y_test, y_test_pred)
print('Out-of-Sample Accuracy:', round(os_accuracy, 3), '\n')

# We can measure the out-of-sample simulated investment performance
os_pred = pd.Series(y_test_pred.astype('int64'), index = y_test.index).rename('Winner')
ret, dia = ml_analysis(os_pred, prices.squeeze())
display(dia)
# Out:
# C:\Users\franc\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Out-of-Sample Accuracy: 0.502
#                      0         1  Benchmark    Active   Neutral
# Mean Return  -0.076821 -0.095356   0.020878 -0.096241  0.005800
# St. Dev.      0.326704  0.288578   0.248453  0.135608  0.212265
# RR Ratio     -0.235140 -0.330434   0.084032 -0.709702  0.027326
# % Positive    0.468085  0.488889   0.617021  0.622222  0.622222
# Worst Month  -0.277496 -0.330311  -0.279488 -0.140106 -0.146796
# Best Month    0.229200  0.234464   0.163447  0.086311  0.104844
# Max DrawDown -0.631450 -0.487233  -0.452643 -0.285287 -0.498007

# %%
gbt_features = pd.DataFrame(gbt.feature_importances_, columns=['Feature Importance'], index=X.columns)
gbt_features
# Out:
#                Feature Importance
# gp                       0.028053
# mom12                    0.040246
# epq                      0.059438
# n_beta                   0.040609
# fed_rate                 0.349160
# unemploy_rate            0.482495

# %%
# We can even plot it if we want
gbt_features[gbt_features['Feature Importance']>0].plot(kind='pie', 
                                                        y='Feature Importance',
                                                        figsize=(10,6),
                                                        fontsize=14)
# Out:
# <AxesSubplot:ylabel='Feature Importance'>
